# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import pearsonr, spearmanr
import statsmodels.stats.multitest as multi

# %% [markdown]
# ## Settings

# %%
sns.set_style("white")
colors = ['#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02']
#flatui = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33']
#flatui = ['#7fc97f','#beaed4','#fdc086','#ffff99','#386cb0','#f0027f']
sns.set_palette(colors)

# %%
x_size, y_size = 12,8
plt.rcParams.update({'font.size': 12})

# %% [markdown]
# # Read the data

# %%
df = pd.read_csv("data\\google_data_preprocessed.csv", encoding="utf8")

# %%
df = df[["date", "hour", "route_id", "workday", "weather", "pace"]]
#df = df[["date", "hour", "route_id", "workday", "pace"]]

# %% [markdown]
# # Rescale per hour

# %%
df = df.groupby(["date", "hour", "route_id", "workday", "weather"], as_index=False).mean()
#df = df.groupby(["date", "hour", "route_id", "workday"], as_index=False).mean()

# %% [markdown]
# # Counters per route

# %%
f = open("data\\counters_per_route.txt", encoding="utf8")
route_counters = {}

for l in f:
    ss = l.strip().split(";")
    route_id = ss[0] 
    route_id = int(route_id)
    cs = ss[1:]    
    if cs != ['']:
        route_counters[route_id] = cs
    
 
    
route_counters
# Out:
# {0: ['1016-140', '1034-216-1', '1038-276', '1025-116'],
#  1: ['1016-140', '1947-211', '1946-230-1'],
#  2: ['1935-230', '1035-136'],
#  3: ['1014-150'],
#  4: ['1001-156', '1021-156'],
#  5: ['0174-1', '0855-1', '1010-1']}

# %% [markdown]
# # Prepare the main df

# %%
df_orig = df.copy()

for counters in route_counters.values():
    for counter_id in counters:
        df[counter_id] = np.nan

# %% [markdown]
# # Read counter data

# %%
df_counters = pd.read_csv("data\counters.csv", encoding="utf8")

# %%
#df_counters = df_counters[["date", "time", "counter_id_direction", "count"]]
#df_counters.columns = ["date", "hour", "counter_id", "count"]
df_counters = df_counters[["date", "time", "counter_id", "count"]]

# %%
# Test: odstrani avtocesto
#df_counters = df_counters[df_counters["counter_id"] != 'HC-H3, LJ (S obvoznica) : LJ (Celovška - Dunajska)']

# %%
for route_id, counters in route_counters.items():
    
    for counter_id in counters:
        if not counter_id:
            continue       
        
        print(counter_id, route_id)
        
        df3 = df_counters[df_counters["counter_id"]==counter_id].copy()
        df3 = df3.drop(columns=["counter_id"])
        df3.columns = ["date", "hour", counter_id]
        df3["route_id"] = route_id
        
        df2 = pd.merge(df_orig, df3, how="left", on=["route_id", "date", "hour"])
        df.update(df2)
# Out:
# 1016-140 0
# 1034-216-1 0
# 1038-276 0
# 1025-116 0
# 1016-140 1
# 1947-211 1
# 1946-230-1 1
# 1935-230 2
# 1035-136 2
# 1014-150 3
# 1001-156 4
# 1021-156 4
# 0174-1 5
# 0855-1 5
# 1010-1 5

# %%
df.to_csv("data\\counter_hours.csv", index=False)

# %% [markdown]
# # Pairplots and correlations

# %%
#route_counters2 = {3:route_counters[3]}

# %%
def corrfunc(x,y, ax=None, **kws):
    """Plot the correlation coefficient in the top left hand corner of a plot."""
    r_P, _ = pearsonr(x, y)
    r_S, _ = spearmanr(x, y)
    ax = ax or plt.gca()
    # Unicode for lowercase rho (ρ)
    rho_P = '$r_P$'
    rho_S = '$r_S$'#'\u03C1$'
    ax.annotate(f'{rho_P} = {r_P:.2f}, {rho_S} = {r_S:.2f}', xy=(.1, .9), xycoords=ax.transAxes)

# %%
df_corr = pd.DataFrame(columns=["route_id", "counter_id", "Pearson_r", "Pearson_p", "Pearson_q", "Spearman_r", "Spearman_p", "Spearman_q"])

for i, (route_id, counters) in enumerate(route_counters.items()):    
    
    sns.set_palette([colors[i]])
    
    
    df2 = df[df["route_id"]==route_id][["pace"] + counters].copy()
    df2 = df2.dropna(axis='columns', how="all")
    df2 = df2.dropna(axis="rows")
            
    g = sns.pairplot(df2, y_vars = ["pace"], x_vars = df2.columns[1:], kind="reg", plot_kws=dict(scatter_kws=dict(s=10)))    
    g.map(corrfunc)
    #g.map_lower(corrfunc)
    g.fig.suptitle("route ID: " + str(int(route_id)), y=1) # y= some height>1
    plt.savefig("figs\\pairplots\\route_"+str(int(route_id))+"_pairplot_small.pdf", bbox_inches="tight")
    plt.savefig("figs\\pairplots\\route_"+str(int(route_id))+"_pairplot_small.png", bbox_inches="tight")
    plt.savefig("figs\\pairplots\\route_"+str(int(route_id))+"_pairplot_small.svg", bbox_inches="tight")
    
    
    plt.show()
    
    
    g = sns.pairplot(df2, kind="reg", plot_kws=dict(scatter_kws=dict(s=10)))  
    #g.map(corrfunc)
    g.map_lower(corrfunc)
    g.map_upper(corrfunc)
    g.fig.suptitle("route ID: " + str(int(route_id)), y=1) # y= some height>1
    plt.savefig("figs\\pairplots\\route_"+str(int(route_id))+"_pairplot.pdf", bbox_inches="tight")
    plt.savefig("figs\\pairplots\\route_"+str(int(route_id))+"_pairplot.png", bbox_inches="tight")
    plt.savefig("figs\\pairplots\\route_"+str(int(route_id))+"_pairplot.svg", bbox_inches="tight")
    
    
    plt.show()
    
    Y = df2["pace"].values
    for counter in df2.columns[1:]:
        X = df2[counter].values
        p_r,p_p = pearsonr(X,Y)
        s_r,s_p = spearmanr(X,Y)
        
        
        df_corr = df_corr.append(pd.DataFrame({"route_id": [route_id],
                                               "counter_id": [counter],
                                               "Pearson_r": [p_r],
                                               "Pearson_p": [p_p],
                                               "Spearman_r": [s_r],
                                               "Spearman_p": [s_p]}), ignore_index=True, sort = False)
            
            
        

df_corr["Pearson_q"] = multi.multipletests(df_corr["Pearson_p"], method = 'fdr_bh')[1]
df_corr["Spearman_q"] = multi.multipletests(df_corr["Spearman_p"], method = 'fdr_bh')[1]

# %%
#s_r,s_p = spearmanr(X,Y)
#p_r,p_p = pearsonr(X,Y)
#df_corr.to_csv("regression_results\\correlations.csv", index=False)

# %%
df_corr2 = df_corr
df_corr2.columns = ["route ID", "counter ID", "r_P", "p(r_P)", "q(r_P)", "r_S", "p(r_S)", "q(r_S)"]
df_corr2[df_corr2.columns[2:]] = df_corr2[df_corr2.columns[2:]].applymap(lambda x: round(x,2))
df_corr2.to_csv("regression_results\\correlations.csv", index=False, sep="\t")

# %%
route_counters2 = {}
route_counters2[2] = route_counters[2]
for i, (route_id, counters) in enumerate(route_counters2.items()):    
    
    sns.set_palette([colors[i]])
    
    
    df2 = df[df["route_id"]==route_id][["pace"] + counters].copy()
    df2 = df2.dropna(axis='columns', how="all")
    
            
    sns.pairplot(df2.dropna(axis="rows"), kind="reg", plot_kws=dict(scatter_kws=dict(s=10)))
    plt.title("route ID: " + str(int(route_id)))
    plt.show()

# %%
df[(~df['1935-230'].isna()) & (df['route_id']==2)]
# Out:
#             date  hour  route_id  workday weather      pace  1016-140  \
# 2     2020-10-04    23         2        0    good  0.134565       NaN
# 8     2020-10-05     0         2        1    good  0.131214       NaN
# 14    2020-10-05     1         2        1    good  0.137508       NaN
# 20    2020-10-05     2         2        1    good  0.136467       NaN
# 26    2020-10-05     3         2        1    good  0.130037       NaN
# 32    2020-10-05     4         2        1    good  0.131894       NaN
# 38    2020-10-05     5         2        1    good  0.139591       NaN
# 44    2020-10-05     6         2        1    good  0.163543       NaN
# 50    2020-10-05     7         2        1    good  0.194648       NaN
# 56    2020-10-05     8         2        1    good  0.206239       NaN
# 62    2020-10-05     9         2        1    good  0.171647       NaN
# 68    2020-10-05    10         2        1    good  0.169202       NaN
# 74    2020-10-05    11         2        1    good  0.168659       NaN
# 80    2020-10-05    12         2        1    good  0.169112       NaN
# 86    2020-10-05    13         2        1    good  0.164267       NaN
# 92    2020-10-05    14         2        1    good  0.172326       NaN
# 98    2020-10-05    15         2        1    good  0.211129       NaN
# 104   2020-10-05    16         2        1    good  0.242733       NaN
# 110   2020-10-05    17         2        1    good  0.178756       NaN
# 116   2020-10-05    18         2        1    good  0.160554       NaN
# 122   2020-10-05    19         2        1    good  0.162275       NaN
# 128   2020-10-05    20         2        1    good  0.155981       NaN
# 134   2020-10-05    21         2        1    good  0.145522       NaN
# 140   2020-10-05    22         2        1    good  0.149008       NaN
# 146   2020-10-05    23         2        1    good  0.147016       NaN
# 152   2020-10-06     0         2        1    good  0.137734       NaN
# 158   2020-10-06     1         2        1    good  0.147786       NaN
# 164   2020-10-06     2         2        1    good  0.139138       NaN
# 170   2020-10-06     3         2        1    good  0.140813       NaN
# 176   2020-10-06     4         2        1    good  0.131486       NaN
# ...          ...   ...       ...      ...     ...       ...       ...
# 3920  2020-11-07    18         2        0    good  0.140089       NaN
# 3926  2020-11-07    19         2        0    good  0.138413       NaN
# 3932  2020-11-07    20         2        0    good  0.137870       NaN
# 3938  2020-11-07    21         2        0    good  0.141175       NaN
# 3944  2020-11-07    22         2        0    good  0.142987       NaN
# 3950  2020-11-07    23         2        0    good  0.134338       NaN
# 3956  2020-11-08     0         2        0     bad  0.130671       NaN
# 3962  2020-11-08     1         2        0     bad  0.125736       NaN
# 3968  2020-11-08     2         2        0     bad  0.122295       NaN
# 3974  2020-11-08     3         2        0     bad  0.128905       NaN
# 3980  2020-11-08     4         2        0     bad  0.125374       NaN
# 3986  2020-11-08     5         2        0     bad  0.121887       NaN
# 3992  2020-11-08     6         2        0     bad  0.129449       NaN
# 3998  2020-11-08     7         2        0     bad  0.126415       NaN
# 4004  2020-11-08     8         2        0     bad  0.128498       NaN
# 4010  2020-11-08     9         2        0     bad  0.136783       NaN
# 4016  2020-11-08    10         2        0     bad  0.139138       NaN
# 4022  2020-11-08    11         2        0     bad  0.147741       NaN
# 4028  2020-11-08    12         2        0     bad  0.141628       NaN
# 4034  2020-11-08    13         2        0     bad  0.139138       NaN
# 4040  2020-11-08    14         2        0     bad  0.138640       NaN
# 4046  2020-11-08    15         2        0     bad  0.142126       NaN
# 4052  2020-11-08    16         2        0     bad  0.138776       NaN
# 4058  2020-11-08    17         2        0     bad  0.145522       NaN
# 4064  2020-11-08    18         2        0     bad  0.140542       NaN
# 4070  2020-11-08    19         2        0     bad  0.139772       NaN
# 4076  2020-11-08    20         2        0     bad  0.136738       NaN
# 4082  2020-11-08    21         2        0     bad  0.129811       NaN
# 4088  2020-11-08    22         2        0     bad  0.130897       NaN
# 4094  2020-11-08    23         2        0     bad  0.131033       NaN
#
#       1034-216-1  1038-276  1025-116  1947-211  1946-230-1  1935-230  \
# 2            NaN       NaN       NaN       NaN         NaN      16.0
# 8            NaN       NaN       NaN       NaN         NaN       2.0
# 14           NaN       NaN       NaN       NaN         NaN       3.0
# 20           NaN       NaN       NaN       NaN         NaN       2.0
# 26           NaN       NaN       NaN       NaN         NaN       3.0
# 32           NaN       NaN       NaN       NaN         NaN      13.0
# 38           NaN       NaN       NaN       NaN         NaN      33.0
# 44           NaN       NaN       NaN       NaN         NaN      69.0
# 50           NaN       NaN       NaN       NaN         NaN     153.0
# 56           NaN       NaN       NaN       NaN         NaN     188.0
# 62           NaN       NaN       NaN       NaN         NaN     123.0
# 68           NaN       NaN       NaN       NaN         NaN     114.0
# 74           NaN       NaN       NaN       NaN         NaN      93.0
# 80           NaN       NaN       NaN       NaN         NaN     118.0
# 86           NaN       NaN       NaN       NaN         NaN     154.0
# 92           NaN       NaN       NaN       NaN         NaN     256.0
# 98           NaN       NaN       NaN       NaN         NaN     244.0
# 104          NaN       NaN       NaN       NaN         NaN     272.0
# 110          NaN       NaN       NaN       NaN         NaN     210.0
# 116          NaN       NaN       NaN       NaN         NaN     153.0
# 122          NaN       NaN       NaN       NaN         NaN     122.0
# 128          NaN       NaN       NaN       NaN         NaN      87.0
# 134          NaN       NaN       NaN       NaN         NaN      69.0
# 140          NaN       NaN       NaN       NaN         NaN      32.0
# 146          NaN       NaN       NaN       NaN         NaN      14.0
# 152          NaN       NaN       NaN       NaN         NaN       7.0
# 158          NaN       NaN       NaN       NaN         NaN       5.0
# 164          NaN       NaN       NaN       NaN         NaN       4.0
# 170          NaN       NaN       NaN       NaN         NaN       7.0
# 176          NaN       NaN       NaN       NaN         NaN      33.0
# ...          ...       ...       ...       ...         ...       ...
# 3920         NaN       NaN       NaN       NaN         NaN      57.0
# 3926         NaN       NaN       NaN       NaN         NaN      45.0
# 3932         NaN       NaN       NaN       NaN         NaN      41.0
# 3938         NaN       NaN       NaN       NaN         NaN      13.0
# 3944         NaN       NaN       NaN       NaN         NaN       8.0
# 3950         NaN       NaN       NaN       NaN         NaN       2.0
# 3956         NaN       NaN       NaN       NaN         NaN       0.0
# 3962         NaN       NaN       NaN       NaN         NaN       1.0
# 3968         NaN       NaN       NaN       NaN         NaN       0.0
# 3974         NaN       NaN       NaN       NaN         NaN       0.0
# 3980         NaN       NaN       NaN       NaN         NaN       0.0
# 3986         NaN       NaN       NaN       NaN         NaN       8.0
# 3992         NaN       NaN       NaN       NaN         NaN       8.0
# 3998         NaN       NaN       NaN       NaN         NaN      11.0
# 4004         NaN       NaN       NaN       NaN         NaN      11.0
# 4010         NaN       NaN       NaN       NaN         NaN      20.0
# 4016         NaN       NaN       NaN       NaN         NaN      31.0
# 4022         NaN       NaN       NaN       NaN         NaN      47.0
# 4028         NaN       NaN       NaN       NaN         NaN      78.0
# 4034         NaN       NaN       NaN       NaN         NaN      96.0
# 4040         NaN       NaN       NaN       NaN         NaN     141.0
# 4046         NaN       NaN       NaN       NaN         NaN     173.0
# 4052         NaN       NaN       NaN       NaN         NaN     136.0
# 4058         NaN       NaN       NaN       NaN         NaN      69.0
# 4064         NaN       NaN       NaN       NaN         NaN      55.0
# 4070         NaN       NaN       NaN       NaN         NaN      33.0
# 4076         NaN       NaN       NaN       NaN         NaN      35.0
# 4082         NaN       NaN       NaN       NaN         NaN      11.0
# 4088         NaN       NaN       NaN       NaN         NaN       6.0
# 4094         NaN       NaN       NaN       NaN         NaN       2.0
#
#       1035-136  1014-150  1001-156  1021-156  0174-1  0855-1  1010-1
# 2          NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 8          NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 14         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 20         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 26         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 32         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 38         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 44         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 50         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 56         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 62         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 68         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 74         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 80         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 86         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 92         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 98         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 104        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 110        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 116        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 122        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 128        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 134        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 140        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 146        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 152        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 158        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 164        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 170        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 176        NaN       NaN       NaN       NaN     NaN     NaN     NaN
# ...        ...       ...       ...       ...     ...     ...     ...
# 3920       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3926       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3932       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3938       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3944       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3950       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3956       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3962       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3968       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3974       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3980       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3986       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3992       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3998       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4004       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4010       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4016       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4022       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4028       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4034       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4040       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4046       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4052       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4058       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4064       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4070       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4076       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4082       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4088       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4094       NaN       NaN       NaN       NaN     NaN     NaN     NaN
#
# [683 rows x 20 columns]

# %%
df
# Out:
#             date  hour  route_id  workday weather      pace  1016-140  \
# 0     2020-10-04    23         0        0    good  0.114544       NaN
# 1     2020-10-04    23         1        0    good  0.132463       NaN
# 2     2020-10-04    23         2        0    good  0.134565       NaN
# 3     2020-10-04    23         3        0    good  0.137983       NaN
# 4     2020-10-04    23         4        0    good  0.125304       NaN
# 5     2020-10-04    23         5        0    good  0.052332       NaN
# 6     2020-10-05     0         0        1    good  0.111981       NaN
# 7     2020-10-05     0         1        1    good  0.129918       NaN
# 8     2020-10-05     0         2        1    good  0.131214       NaN
# 9     2020-10-05     0         3        1    good  0.142058       NaN
# 10    2020-10-05     0         4        1    good  0.115752       NaN
# 11    2020-10-05     0         5        1    good  0.052051       NaN
# 12    2020-10-05     1         0        1    good  0.116333       NaN
# 13    2020-10-05     1         1        1    good  0.129547       NaN
# 14    2020-10-05     1         2        1    good  0.137508       NaN
# 15    2020-10-05     1         3        1    good  0.140700       NaN
# 16    2020-10-05     1         4        1    good  0.116885       NaN
# 17    2020-10-05     1         5        1    good  0.053429       NaN
# 18    2020-10-05     2         0        1    good  0.111280       NaN
# 19    2020-10-05     2         1        1    good  0.123345       NaN
# 20    2020-10-05     2         2        1    good  0.136467       NaN
# 21    2020-10-05     2         3        1    good  0.142818       NaN
# 22    2020-10-05     2         4        1    good  0.120164       NaN
# 23    2020-10-05     2         5        1    good  0.055502       NaN
# 24    2020-10-05     3         0        1    good  0.116309       NaN
# 25    2020-10-05     3         1        1    good  0.119828       NaN
# 26    2020-10-05     3         2        1    good  0.130037       NaN
# 27    2020-10-05     3         3        1    good  0.147164       NaN
# 28    2020-10-05     3         4        1    good  0.121701       NaN
# 29    2020-10-05     3         5        1    good  0.056278       NaN
# ...          ...   ...       ...      ...     ...       ...       ...
# 4068  2020-11-08    19         0        0     bad  0.120612     303.0
# 4069  2020-11-08    19         1        0     bad  0.134639     303.0
# 4070  2020-11-08    19         2        0     bad  0.139772       NaN
# 4071  2020-11-08    19         3        0     bad  0.140048       NaN
# 4072  2020-11-08    19         4        0     bad  0.128299       NaN
# 4073  2020-11-08    19         5        0     bad  0.056987       NaN
# 4074  2020-11-08    20         0        0     bad  0.119162     251.0
# 4075  2020-11-08    20         1        0     bad  0.131908     251.0
# 4076  2020-11-08    20         2        0     bad  0.136738       NaN
# 4077  2020-11-08    20         3        0     bad  0.141406       NaN
# 4078  2020-11-08    20         4        0     bad  0.128299       NaN
# 4079  2020-11-08    20         5        0     bad  0.055863       NaN
# 4080  2020-11-08    21         0        0     bad  0.114206      56.0
# 4081  2020-11-08    21         1        0     bad  0.124595      56.0
# 4082  2020-11-08    21         2        0     bad  0.129811       NaN
# 4083  2020-11-08    21         3        0     bad  0.129998       NaN
# 4084  2020-11-08    21         4        0     bad  0.130079       NaN
# 4085  2020-11-08    21         5        0     bad  0.053455       NaN
# 4086  2020-11-08    22         0        0     bad  0.113940      29.0
# 4087  2020-11-08    22         1        0     bad  0.128205      29.0
# 4088  2020-11-08    22         2        0     bad  0.130897       NaN
# 4089  2020-11-08    22         3        0     bad  0.130813       NaN
# 4090  2020-11-08    22         4        0     bad  0.128622       NaN
# 4091  2020-11-08    22         5        0     bad  0.052626       NaN
# 4092  2020-11-08    23         0        0     bad  0.114689      22.0
# 4093  2020-11-08    23         1        0     bad  0.132000      22.0
# 4094  2020-11-08    23         2        0     bad  0.131033       NaN
# 4095  2020-11-08    23         3        0     bad  0.128314       NaN
# 4096  2020-11-08    23         4        0     bad  0.124737       NaN
# 4097  2020-11-08    23         5        0     bad  0.054017       NaN
#
#       1034-216-1  1038-276  1025-116  1947-211  1946-230-1  1935-230  \
# 0           57.0       NaN       NaN       NaN         NaN       NaN
# 1            NaN       NaN       NaN       NaN         NaN       NaN
# 2            NaN       NaN       NaN       NaN         NaN      16.0
# 3            NaN       NaN       NaN       NaN         NaN       NaN
# 4            NaN       NaN       NaN       NaN         NaN       NaN
# 5            NaN       NaN       NaN       NaN         NaN       NaN
# 6           27.0       NaN       NaN       NaN         NaN       NaN
# 7            NaN       NaN       NaN       NaN         NaN       NaN
# 8            NaN       NaN       NaN       NaN         NaN       2.0
# 9            NaN       NaN       NaN       NaN         NaN       NaN
# 10           NaN       NaN       NaN       NaN         NaN       NaN
# 11           NaN       NaN       NaN       NaN         NaN       NaN
# 12          14.0       NaN       NaN       NaN         NaN       NaN
# 13           NaN       NaN       NaN       NaN         NaN       NaN
# 14           NaN       NaN       NaN       NaN         NaN       3.0
# 15           NaN       NaN       NaN       NaN         NaN       NaN
# 16           NaN       NaN       NaN       NaN         NaN       NaN
# 17           NaN       NaN       NaN       NaN         NaN       NaN
# 18          16.0       NaN       NaN       NaN         NaN       NaN
# 19           NaN       NaN       NaN       NaN         NaN       NaN
# 20           NaN       NaN       NaN       NaN         NaN       2.0
# 21           NaN       NaN       NaN       NaN         NaN       NaN
# 22           NaN       NaN       NaN       NaN         NaN       NaN
# 23           NaN       NaN       NaN       NaN         NaN       NaN
# 24          10.0       NaN       NaN       NaN         NaN       NaN
# 25           NaN       NaN       NaN       NaN         NaN       NaN
# 26           NaN       NaN       NaN       NaN         NaN       3.0
# 27           NaN       NaN       NaN       NaN         NaN       NaN
# 28           NaN       NaN       NaN       NaN         NaN       NaN
# 29           NaN       NaN       NaN       NaN         NaN       NaN
# ...          ...       ...       ...       ...         ...       ...
# 4068       178.0      84.0      55.0       NaN         NaN       NaN
# 4069         NaN       NaN       NaN      11.0         NaN       NaN
# 4070         NaN       NaN       NaN       NaN         NaN      33.0
# 4071         NaN       NaN       NaN       NaN         NaN       NaN
# 4072         NaN       NaN       NaN       NaN         NaN       NaN
# 4073         NaN       NaN       NaN       NaN         NaN       NaN
# 4074       159.0      85.0      55.0       NaN         NaN       NaN
# 4075         NaN       NaN       NaN      10.0         NaN       NaN
# 4076         NaN       NaN       NaN       NaN         NaN      35.0
# 4077         NaN       NaN       NaN       NaN         NaN       NaN
# 4078         NaN       NaN       NaN       NaN         NaN       NaN
# 4079         NaN       NaN       NaN       NaN         NaN       NaN
# 4080        52.0      30.0      31.0       NaN         NaN       NaN
# 4081         NaN       NaN       NaN       3.0         NaN       NaN
# 4082         NaN       NaN       NaN       NaN         NaN      11.0
# 4083         NaN       NaN       NaN       NaN         NaN       NaN
# 4084         NaN       NaN       NaN       NaN         NaN       NaN
# 4085         NaN       NaN       NaN       NaN         NaN       NaN
# 4086        25.0       7.0      23.0       NaN         NaN       NaN
# 4087         NaN       NaN       NaN       1.0         NaN       NaN
# 4088         NaN       NaN       NaN       NaN         NaN       6.0
# 4089         NaN       NaN       NaN       NaN         NaN       NaN
# 4090         NaN       NaN       NaN       NaN         NaN       NaN
# 4091         NaN       NaN       NaN       NaN         NaN       NaN
# 4092         2.0       2.0       8.0       NaN         NaN       NaN
# 4093         NaN       NaN       NaN       0.0         NaN       NaN
# 4094         NaN       NaN       NaN       NaN         NaN       2.0
# 4095         NaN       NaN       NaN       NaN         NaN       NaN
# 4096         NaN       NaN       NaN       NaN         NaN       NaN
# 4097         NaN       NaN       NaN       NaN         NaN       NaN
#
#       1035-136  1014-150  1001-156  1021-156  0174-1  0855-1  1010-1
# 0          NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 1          NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 2          NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 3          NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4          NaN       NaN     102.0      78.0     NaN     NaN     NaN
# 5          NaN       NaN       NaN       NaN   201.0   321.0   165.0
# 6          NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 7          NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 8          NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 9          NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 10         NaN       NaN      37.0      51.0     NaN     NaN     NaN
# 11         NaN       NaN       NaN       NaN   111.0   211.0    92.0
# 12         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 13         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 14         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 15         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 16         NaN       NaN      23.0      27.0     NaN     NaN     NaN
# 17         NaN       NaN       NaN       NaN    72.0   199.0    65.0
# 18         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 19         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 20         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 21         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 22         NaN       NaN      23.0      31.0     NaN     NaN     NaN
# 23         NaN       NaN       NaN       NaN    85.0   179.0    58.0
# 24         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 25         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 26         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 27         NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 28         NaN       NaN      18.0      28.0     NaN     NaN     NaN
# 29         NaN       NaN       NaN       NaN    93.0   187.0    62.0
# ...        ...       ...       ...       ...     ...     ...     ...
# 4068       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4069       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4070       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4071       NaN     254.0       NaN       NaN     NaN     NaN     NaN
# 4072       NaN       NaN     331.0     286.0     NaN     NaN     NaN
# 4073       NaN       NaN       NaN       NaN   662.0   853.0   560.0
# 4074       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4075       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4076       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4077       NaN     213.0       NaN       NaN     NaN     NaN     NaN
# 4078       NaN       NaN     272.0     230.0     NaN     NaN     NaN
# 4079       NaN       NaN       NaN       NaN   529.0   707.0   467.0
# 4080       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4081       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4082       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4083       NaN      82.0       NaN       NaN     NaN     NaN     NaN
# 4084       NaN       NaN      64.0      80.0     NaN     NaN     NaN
# 4085       NaN       NaN       NaN       NaN   186.0   294.0   135.0
# 4086       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4087       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4088       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4089       NaN      32.0       NaN       NaN     NaN     NaN     NaN
# 4090       NaN       NaN      15.0      30.0     NaN     NaN     NaN
# 4091       NaN       NaN       NaN       NaN    92.0   190.0    74.0
# 4092       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4093       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4094       NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4095       NaN      17.0       NaN       NaN     NaN     NaN     NaN
# 4096       NaN       NaN      16.0      18.0     NaN     NaN     NaN
# 4097       NaN       NaN       NaN       NaN    63.0   143.0    57.0
#
# [4098 rows x 20 columns]

# %% [markdown]
# # Data export

# %%
df.to_csv("data\\pace_counters.csv", encoding="utf8", index=False)

# %% [markdown]
# # Remove route info

# %%
#df2 = df.drop(columns=["route_id", "pace"]).copy()
#df2 = df2.groupby(['date','hour','weather'], as_index=False).max()
#df2 = df2.dropna(axis='columns', how="all")

# %%
#df2.to_csv("data\\counters_filtered.csv", encoding="utf8", index=False)
